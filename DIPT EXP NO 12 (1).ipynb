# %% [markdown]
# # Face Detection with Haar Cascades
# Note: This is face detection NOT face recognition. We are only detecting if a face is in an image, not who the face actually is. That requires deep learning.
#
# Name : SANTHOSH KUMAR A
# Reg. No. : 212224230250

# %%
import numpy as np
import cv2 
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
with_out_glass =cv2.imread("C:\\Users\\admin\\Downloads\\boy without glasses.png",0)
with_glass = cv2.imread("C:\\Users\\admin\\Downloads\\boy.png",0)
group_photo = cv2.imread("C:\\Users\\admin\\Downloads\\group of people.png",0)

# %%
plt.imshow(with_glass,cmap='gray')

# %%
plt.imshow(with_out_glass,cmap='gray')

# %%
plt.imshow(group_photo,cmap='gray')

# %% [markdown]
# # II) Load Haar Cascade Classifiers
#        Step 1: Load face and eye cascade XML files
# ## Face Detection

# %%
face_cascade = cv2.CascadeClassifier("C:\\Users\\admin\\Downloads\\haarcascade_frontalface_default.xml")

# %%
def detect_face(img):
    face_img = img.copy()
    face_rects = face_cascade.detectMultiScale(face_img) 
    
    for (x,y,w,h) in face_rects: 
        cv2.rectangle(face_img, (x,y), (x+w,y+h), (255,0,0), 2) 
        
    return face_img

# %%
result = detect_face(with_glass)

# %%
plt.imshow(result,cmap='gray')

# %%
result = detect_face(with_out_glass)
plt.imshow(result,cmap='gray')

# %%
result = detect_face(group_photo)
plt.imshow(result,cmap='gray')

# %%
def adj_detect_face(img):
    
    face_img = img.copy()
  
    face_rects = face_cascade.detectMultiScale(face_img,scaleFactor=1.2, minNeighbors=5) 
    
    for (x,y,w,h) in face_rects: 
        cv2.rectangle(face_img, (x,y), (x+w,y+h), (255,255,255), 2) 
        
    return face_img

# %%
result = adj_detect_face(group_photo)
plt.imshow(result,cmap='gray')

# %%
eye_cascade = cv2.CascadeClassifier("C:\\Users\\admin\\Downloads\\haarcascade_eye.xml")

# %%
def detect_eyes(img):
    
    face_img = img.copy()
  
    eyes = eye_cascade.detectMultiScale(face_img) 
    
    
    for (x,y,w,h) in eyes: 
        cv2.rectangle(face_img, (x,y), (x+w,y+h), (255,255,255), 2) 
        
    return face_img

# %%
result = detect_eyes(with_glass)
plt.imshow(result,cmap='gray')

# %%
eyes = eye_cascade.detectMultiScale(with_out_glass)

# %%
result = detect_eyes(group_photo)
plt.imshow(result,cmap='gray')
